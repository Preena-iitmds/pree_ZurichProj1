# %%
# !curl "https://api.github.com/search/users?q=location:Zurich+followers:>50"
# Out:
# {
#   "total_count": 474,
#   "incomplete_results": false,
#   "items": [
#     {
#       "login": "IDouble",
#       "id": 18186995,
#       "node_id": "MDQ6VXNlcjE4MTg2OTk1",
#       "avatar_url": "https://avatars.githubusercontent.com/u/18186995?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/IDouble",
#       "html_url": "https://github.com/IDouble",
#       "followers_url": "https://api.github.com/users/IDouble/followers",
#       "following_url": "https://api.github.com/users/IDouble/following{/other_user}",
#       "gists_url": "https://api.github.com/users/IDouble/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/IDouble/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/IDouble/subscriptions",
#       "organizations_url": "https://api.github.com/users/IDouble/orgs",
#       "repos_url": "https://api.github.com/users/IDouble/repos",
#       "events_url": "https://api.github.com/users/IDouble/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/IDouble/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "TheOfficialFloW",
#       "id": 14246466,
#       "node_id": "MDQ6VXNlcjE0MjQ2NDY2",
#       "avatar_url": "https://avatars.githubusercontent.com/u/14246466?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/TheOfficialFloW",
#       "html_url": "https://github.com/TheOfficialFloW",
#       "followers_url": "https://api.github.com/users/TheOfficialFloW/followers",
#       "following_url": "https://api.github.com/users/TheOfficialFloW/following{/other_user}",
#       "gists_url": "https://api.github.com/users/TheOfficialFloW/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/TheOfficialFloW/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/TheOfficialFloW/subscriptions",
#       "organizations_url": "https://api.github.com/users/TheOfficialFloW/orgs",
#       "repos_url": "https://api.github.com/users/TheOfficialFloW/repos",
#       "events_url": "https://api.github.com/users/TheOfficialFloW/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/TheOfficialFloW/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "Seldaek",
#       "id": 183678,
#       "node_id": "MDQ6VXNlcjE4MzY3OA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/183678?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Seldaek",
#       "html_url": "https://github.com/Seldaek",
#       "followers_url": "https://api.github.com/users/Seldaek/followers",
#       "following_url": "https://api.github.com/users/Seldaek/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Seldaek/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Seldaek/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Seldaek/subscriptions",
#       "organizations_url": "https://api.github.com/users/Seldaek/orgs",
#       "repos_url": "https://api.github.com/users/Seldaek/repos",
#       "events_url": "https://api.github.com/users/Seldaek/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Seldaek/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "riscv",
#       "id": 10872782,
#       "node_id": "MDEyOk9yZ2FuaXphdGlvbjEwODcyNzgy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/10872782?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/riscv",
#       "html_url": "https://github.com/riscv",
#       "followers_url": "https://api.github.com/users/riscv/followers",
#       "following_url": "https://api.github.com/users/riscv/following{/other_user}",
#       "gists_url": "https://api.github.com/users/riscv/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/riscv/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/riscv/subscriptions",
#       "organizations_url": "https://api.github.com/users/riscv/orgs",
#       "repos_url": "https://api.github.com/users/riscv/repos",
#       "events_url": "https://api.github.com/users/riscv/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/riscv/received_events",
#       "type": "Organization",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "JonnyBurger",
#       "id": 1629785,
#       "node_id": "MDQ6VXNlcjE2Mjk3ODU=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1629785?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/JonnyBurger",
#       "html_url": "https://github.com/JonnyBurger",
#       "followers_url": "https://api.github.com/users/JonnyBurger/followers",
#       "following_url": "https://api.github.com/users/JonnyBurger/following{/other_user}",
#       "gists_url": "https://api.github.com/users/JonnyBurger/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/JonnyBurger/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/JonnyBurger/subscriptions",
#       "organizations_url": "https://api.github.com/users/JonnyBurger/orgs",
#       "repos_url": "https://api.github.com/users/JonnyBurger/repos",
#       "events_url": "https://api.github.com/users/JonnyBurger/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/JonnyBurger/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "bpasero",
#       "id": 900690,
#       "node_id": "MDQ6VXNlcjkwMDY5MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/900690?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/bpasero",
#       "html_url": "https://github.com/bpasero",
#       "followers_url": "https://api.github.com/users/bpasero/followers",
#       "following_url": "https://api.github.com/users/bpasero/following{/other_user}",
#       "gists_url": "https://api.github.com/users/bpasero/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/bpasero/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/bpasero/subscriptions",
#       "organizations_url": "https://api.github.com/users/bpasero/orgs",
#       "repos_url": "https://api.github.com/users/bpasero/repos",
#       "events_url": "https://api.github.com/users/bpasero/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/bpasero/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": true,
#       "score": 1.0
#     },
#     {
#       "login": "egamma",
#       "id": 172399,
#       "node_id": "MDQ6VXNlcjE3MjM5OQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/172399?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/egamma",
#       "html_url": "https://github.com/egamma",
#       "followers_url": "https://api.github.com/users/egamma/followers",
#       "following_url": "https://api.github.com/users/egamma/following{/other_user}",
#       "gists_url": "https://api.github.com/users/egamma/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/egamma/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/egamma/subscriptions",
#       "organizations_url": "https://api.github.com/users/egamma/orgs",
#       "repos_url": "https://api.github.com/users/egamma/repos",
#       "events_url": "https://api.github.com/users/egamma/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/egamma/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": true,
#       "score": 1.0
#     },
#     {
#       "login": "ethz-asl",
#       "id": 475362,
#       "node_id": "MDEyOk9yZ2FuaXphdGlvbjQ3NTM2Mg==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/475362?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/ethz-asl",
#       "html_url": "https://github.com/ethz-asl",
#       "followers_url": "https://api.github.com/users/ethz-asl/followers",
#       "following_url": "https://api.github.com/users/ethz-asl/following{/other_user}",
#       "gists_url": "https://api.github.com/users/ethz-asl/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/ethz-asl/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/ethz-asl/subscriptions",
#       "organizations_url": "https://api.github.com/users/ethz-asl/orgs",
#       "repos_url": "https://api.github.com/users/ethz-asl/repos",
#       "events_url": "https://api.github.com/users/ethz-asl/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/ethz-asl/received_events",
#       "type": "Organization",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "sahildua2305",
#       "id": 5206277,
#       "node_id": "MDQ6VXNlcjUyMDYyNzc=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/5206277?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/sahildua2305",
#       "html_url": "https://github.com/sahildua2305",
#       "followers_url": "https://api.github.com/users/sahildua2305/followers",
#       "following_url": "https://api.github.com/users/sahildua2305/following{/other_user}",
#       "gists_url": "https://api.github.com/users/sahildua2305/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/sahildua2305/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/sahildua2305/subscriptions",
#       "organizations_url": "https://api.github.com/users/sahildua2305/orgs",
#       "repos_url": "https://api.github.com/users/sahildua2305/repos",
#       "events_url": "https://api.github.com/users/sahildua2305/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/sahildua2305/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "joaomoreno",
#       "id": 22350,
#       "node_id": "MDQ6VXNlcjIyMzUw",
#       "avatar_url": "https://avatars.githubusercontent.com/u/22350?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/joaomoreno",
#       "html_url": "https://github.com/joaomoreno",
#       "followers_url": "https://api.github.com/users/joaomoreno/followers",
#       "following_url": "https://api.github.com/users/joaomoreno/following{/other_user}",
#       "gists_url": "https://api.github.com/users/joaomoreno/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/joaomoreno/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/joaomoreno/subscriptions",
#       "organizations_url": "https://api.github.com/users/joaomoreno/orgs",
#       "repos_url": "https://api.github.com/users/joaomoreno/repos",
#       "events_url": "https://api.github.com/users/joaomoreno/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/joaomoreno/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": true,
#       "score": 1.0
#     },
#     {
#       "login": "klaudiosinani",
#       "id": 12670537,
#       "node_id": "MDQ6VXNlcjEyNjcwNTM3",
#       "avatar_url": "https://avatars.githubusercontent.com/u/12670537?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/klaudiosinani",
#       "html_url": "https://github.com/klaudiosinani",
#       "followers_url": "https://api.github.com/users/klaudiosinani/followers",
#       "following_url": "https://api.github.com/users/klaudiosinani/following{/other_user}",
#       "gists_url": "https://api.github.com/users/klaudiosinani/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/klaudiosinani/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/klaudiosinani/subscriptions",
#       "organizations_url": "https://api.github.com/users/klaudiosinani/orgs",
#       "repos_url": "https://api.github.com/users/klaudiosinani/repos",
#       "events_url": "https://api.github.com/users/klaudiosinani/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/klaudiosinani/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "sbrannen",
#       "id": 104798,
#       "node_id": "MDQ6VXNlcjEwNDc5OA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/104798?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/sbrannen",
#       "html_url": "https://github.com/sbrannen",
#       "followers_url": "https://api.github.com/users/sbrannen/followers",
#       "following_url": "https://api.github.com/users/sbrannen/following{/other_user}",
#       "gists_url": "https://api.github.com/users/sbrannen/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/sbrannen/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/sbrannen/subscriptions",
#       "organizations_url": "https://api.github.com/users/sbrannen/orgs",
#       "repos_url": "https://api.github.com/users/sbrannen/repos",
#       "events_url": "https://api.github.com/users/sbrannen/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/sbrannen/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "Juriy",
#       "id": 460586,
#       "node_id": "MDQ6VXNlcjQ2MDU4Ng==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/460586?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Juriy",
#       "html_url": "https://github.com/Juriy",
#       "followers_url": "https://api.github.com/users/Juriy/followers",
#       "following_url": "https://api.github.com/users/Juriy/following{/other_user}",
#       "gists_url": "https://api.github.com/users/Juriy/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/Juriy/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/Juriy/subscriptions",
#       "organizations_url": "https://api.github.com/users/Juriy/orgs",
#       "repos_url": "https://api.github.com/users/Juriy/repos",
#       "events_url": "https://api.github.com/users/Juriy/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/Juriy/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "sarlinpe",
#       "id": 15985472,
#       "node_id": "MDQ6VXNlcjE1OTg1NDcy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/15985472?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/sarlinpe",
#       "html_url": "https://github.com/sarlinpe",
#       "followers_url": "https://api.github.com/users/sarlinpe/followers",
#       "following_url": "https://api.github.com/users/sarlinpe/following{/other_user}",
#       "gists_url": "https://api.github.com/users/sarlinpe/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/sarlinpe/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/sarlinpe/subscriptions",
#       "organizations_url": "https://api.github.com/users/sarlinpe/orgs",
#       "repos_url": "https://api.github.com/users/sarlinpe/repos",
#       "events_url": "https://api.github.com/users/sarlinpe/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/sarlinpe/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "sustrik",
#       "id": 305718,
#       "node_id": "MDQ6VXNlcjMwNTcxOA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/305718?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/sustrik",
#       "html_url": "https://github.com/sustrik",
#       "followers_url": "https://api.github.com/users/sustrik/followers",
#       "following_url": "https://api.github.com/users/sustrik/following{/other_user}",
#       "gists_url": "https://api.github.com/users/sustrik/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/sustrik/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/sustrik/subscriptions",
#       "organizations_url": "https://api.github.com/users/sustrik/orgs",
#       "repos_url": "https://api.github.com/users/sustrik/repos",
#       "events_url": "https://api.github.com/users/sustrik/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/sustrik/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "LorenzMeier",
#       "id": 1208119,
#       "node_id": "MDQ6VXNlcjEyMDgxMTk=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1208119?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/LorenzMeier",
#       "html_url": "https://github.com/LorenzMeier",
#       "followers_url": "https://api.github.com/users/LorenzMeier/followers",
#       "following_url": "https://api.github.com/users/LorenzMeier/following{/other_user}",
#       "gists_url": "https://api.github.com/users/LorenzMeier/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/LorenzMeier/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/LorenzMeier/subscriptions",
#       "organizations_url": "https://api.github.com/users/LorenzMeier/orgs",
#       "repos_url": "https://api.github.com/users/LorenzMeier/repos",
#       "events_url": "https://api.github.com/users/LorenzMeier/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/LorenzMeier/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "jwagner",
#       "id": 293536,
#       "node_id": "MDQ6VXNlcjI5MzUzNg==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/293536?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/jwagner",
#       "html_url": "https://github.com/jwagner",
#       "followers_url": "https://api.github.com/users/jwagner/followers",
#       "following_url": "https://api.github.com/users/jwagner/following{/other_user}",
#       "gists_url": "https://api.github.com/users/jwagner/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/jwagner/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/jwagner/subscriptions",
#       "organizations_url": "https://api.github.com/users/jwagner/orgs",
#       "repos_url": "https://api.github.com/users/jwagner/repos",
#       "events_url": "https://api.github.com/users/jwagner/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/jwagner/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "jaspervdj",
#       "id": 95501,
#       "node_id": "MDQ6VXNlcjk1NTAx",
#       "avatar_url": "https://avatars.githubusercontent.com/u/95501?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/jaspervdj",
#       "html_url": "https://github.com/jaspervdj",
#       "followers_url": "https://api.github.com/users/jaspervdj/followers",
#       "following_url": "https://api.github.com/users/jaspervdj/following{/other_user}",
#       "gists_url": "https://api.github.com/users/jaspervdj/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/jaspervdj/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/jaspervdj/subscriptions",
#       "organizations_url": "https://api.github.com/users/jaspervdj/orgs",
#       "repos_url": "https://api.github.com/users/jaspervdj/repos",
#       "events_url": "https://api.github.com/users/jaspervdj/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/jaspervdj/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "lsmith77",
#       "id": 300279,
#       "node_id": "MDQ6VXNlcjMwMDI3OQ==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/300279?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lsmith77",
#       "html_url": "https://github.com/lsmith77",
#       "followers_url": "https://api.github.com/users/lsmith77/followers",
#       "following_url": "https://api.github.com/users/lsmith77/following{/other_user}",
#       "gists_url": "https://api.github.com/users/lsmith77/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/lsmith77/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/lsmith77/subscriptions",
#       "organizations_url": "https://api.github.com/users/lsmith77/orgs",
#       "repos_url": "https://api.github.com/users/lsmith77/repos",
#       "events_url": "https://api.github.com/users/lsmith77/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/lsmith77/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "videlalvaro",
#       "id": 30834,
#       "node_id": "MDQ6VXNlcjMwODM0",
#       "avatar_url": "https://avatars.githubusercontent.com/u/30834?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/videlalvaro",
#       "html_url": "https://github.com/videlalvaro",
#       "followers_url": "https://api.github.com/users/videlalvaro/followers",
#       "following_url": "https://api.github.com/users/videlalvaro/following{/other_user}",
#       "gists_url": "https://api.github.com/users/videlalvaro/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/videlalvaro/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/videlalvaro/subscriptions",
#       "organizations_url": "https://api.github.com/users/videlalvaro/orgs",
#       "repos_url": "https://api.github.com/users/videlalvaro/repos",
#       "events_url": "https://api.github.com/users/videlalvaro/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/videlalvaro/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "cvg",
#       "id": 840224,
#       "node_id": "MDEyOk9yZ2FuaXphdGlvbjg0MDIyNA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/840224?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/cvg",
#       "html_url": "https://github.com/cvg",
#       "followers_url": "https://api.github.com/users/cvg/followers",
#       "following_url": "https://api.github.com/users/cvg/following{/other_user}",
#       "gists_url": "https://api.github.com/users/cvg/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/cvg/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/cvg/subscriptions",
#       "organizations_url": "https://api.github.com/users/cvg/orgs",
#       "repos_url": "https://api.github.com/users/cvg/repos",
#       "events_url": "https://api.github.com/users/cvg/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/cvg/received_events",
#       "type": "Organization",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "filipw",
#       "id": 1710369,
#       "node_id": "MDQ6VXNlcjE3MTAzNjk=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1710369?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/filipw",
#       "html_url": "https://github.com/filipw",
#       "followers_url": "https://api.github.com/users/filipw/followers",
#       "following_url": "https://api.github.com/users/filipw/following{/other_user}",
#       "gists_url": "https://api.github.com/users/filipw/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/filipw/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/filipw/subscriptions",
#       "organizations_url": "https://api.github.com/users/filipw/orgs",
#       "repos_url": "https://api.github.com/users/filipw/repos",
#       "events_url": "https://api.github.com/users/filipw/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/filipw/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "SimonHoiberg",
#       "id": 31746424,
#       "node_id": "MDQ6VXNlcjMxNzQ2NDI0",
#       "avatar_url": "https://avatars.githubusercontent.com/u/31746424?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/SimonHoiberg",
#       "html_url": "https://github.com/SimonHoiberg",
#       "followers_url": "https://api.github.com/users/SimonHoiberg/followers",
#       "following_url": "https://api.github.com/users/SimonHoiberg/following{/other_user}",
#       "gists_url": "https://api.github.com/users/SimonHoiberg/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/SimonHoiberg/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/SimonHoiberg/subscriptions",
#       "organizations_url": "https://api.github.com/users/SimonHoiberg/orgs",
#       "repos_url": "https://api.github.com/users/SimonHoiberg/repos",
#       "events_url": "https://api.github.com/users/SimonHoiberg/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/SimonHoiberg/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "daviddao",
#       "id": 1241240,
#       "node_id": "MDQ6VXNlcjEyNDEyNDA=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1241240?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/daviddao",
#       "html_url": "https://github.com/daviddao",
#       "followers_url": "https://api.github.com/users/daviddao/followers",
#       "following_url": "https://api.github.com/users/daviddao/following{/other_user}",
#       "gists_url": "https://api.github.com/users/daviddao/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/daviddao/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/daviddao/subscriptions",
#       "organizations_url": "https://api.github.com/users/daviddao/orgs",
#       "repos_url": "https://api.github.com/users/daviddao/repos",
#       "events_url": "https://api.github.com/users/daviddao/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/daviddao/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "FujiwaraChoki",
#       "id": 78088687,
#       "node_id": "MDQ6VXNlcjc4MDg4Njg3",
#       "avatar_url": "https://avatars.githubusercontent.com/u/78088687?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/FujiwaraChoki",
#       "html_url": "https://github.com/FujiwaraChoki",
#       "followers_url": "https://api.github.com/users/FujiwaraChoki/followers",
#       "following_url": "https://api.github.com/users/FujiwaraChoki/following{/other_user}",
#       "gists_url": "https://api.github.com/users/FujiwaraChoki/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/FujiwaraChoki/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/FujiwaraChoki/subscriptions",
#       "organizations_url": "https://api.github.com/users/FujiwaraChoki/orgs",
#       "repos_url": "https://api.github.com/users/FujiwaraChoki/repos",
#       "events_url": "https://api.github.com/users/FujiwaraChoki/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/FujiwaraChoki/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "sandy081",
#       "id": 10746682,
#       "node_id": "MDQ6VXNlcjEwNzQ2Njgy",
#       "avatar_url": "https://avatars.githubusercontent.com/u/10746682?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/sandy081",
#       "html_url": "https://github.com/sandy081",
#       "followers_url": "https://api.github.com/users/sandy081/followers",
#       "following_url": "https://api.github.com/users/sandy081/following{/other_user}",
#       "gists_url": "https://api.github.com/users/sandy081/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/sandy081/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/sandy081/subscriptions",
#       "organizations_url": "https://api.github.com/users/sandy081/orgs",
#       "repos_url": "https://api.github.com/users/sandy081/repos",
#       "events_url": "https://api.github.com/users/sandy081/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/sandy081/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": true,
#       "score": 1.0
#     },
#     {
#       "login": "mhils",
#       "id": 1019198,
#       "node_id": "MDQ6VXNlcjEwMTkxOTg=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1019198?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/mhils",
#       "html_url": "https://github.com/mhils",
#       "followers_url": "https://api.github.com/users/mhils/followers",
#       "following_url": "https://api.github.com/users/mhils/following{/other_user}",
#       "gists_url": "https://api.github.com/users/mhils/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/mhils/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/mhils/subscriptions",
#       "organizations_url": "https://api.github.com/users/mhils/orgs",
#       "repos_url": "https://api.github.com/users/mhils/repos",
#       "events_url": "https://api.github.com/users/mhils/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/mhils/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "decanus",
#       "id": 7621705,
#       "node_id": "MDQ6VXNlcjc2MjE3MDU=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/7621705?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/decanus",
#       "html_url": "https://github.com/decanus",
#       "followers_url": "https://api.github.com/users/decanus/followers",
#       "following_url": "https://api.github.com/users/decanus/following{/other_user}",
#       "gists_url": "https://api.github.com/users/decanus/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/decanus/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/decanus/subscriptions",
#       "organizations_url": "https://api.github.com/users/decanus/orgs",
#       "repos_url": "https://api.github.com/users/decanus/repos",
#       "events_url": "https://api.github.com/users/decanus/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/decanus/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "simonaco",
#       "id": 1573904,
#       "node_id": "MDQ6VXNlcjE1NzM5MDQ=",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1573904?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/simonaco",
#       "html_url": "https://github.com/simonaco",
#       "followers_url": "https://api.github.com/users/simonaco/followers",
#       "following_url": "https://api.github.com/users/simonaco/following{/other_user}",
#       "gists_url": "https://api.github.com/users/simonaco/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/simonaco/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/simonaco/subscriptions",
#       "organizations_url": "https://api.github.com/users/simonaco/orgs",
#       "repos_url": "https://api.github.com/users/simonaco/repos",
#       "events_url": "https://api.github.com/users/simonaco/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/simonaco/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     },
#     {
#       "login": "vegasbrianc",
#       "id": 674790,
#       "node_id": "MDQ6VXNlcjY3NDc5MA==",
#       "avatar_url": "https://avatars.githubusercontent.com/u/674790?v=4",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/vegasbrianc",
#       "html_url": "https://github.com/vegasbrianc",
#       "followers_url": "https://api.github.com/users/vegasbrianc/followers",
#       "following_url": "https://api.github.com/users/vegasbrianc/following{/other_user}",
#       "gists_url": "https://api.github.com/users/vegasbrianc/gists{/gist_id}",
#       "starred_url": "https://api.github.com/users/vegasbrianc/starred{/owner}{/repo}",
#       "subscriptions_url": "https://api.github.com/users/vegasbrianc/subscriptions",
#       "organizations_url": "https://api.github.com/users/vegasbrianc/orgs",
#       "repos_url": "https://api.github.com/users/vegasbrianc/repos",
#       "events_url": "https://api.github.com/users/vegasbrianc/events{/privacy}",
#       "received_events_url": "https://api.github.com/users/vegasbrianc/received_events",
#       "type": "User",
#       "user_view_type": "public",
#       "site_admin": false,
#       "score": 1.0
#     }
#   ]
# }

# %%
import requests
import time
import pandas as pd

# Replace with your GitHub token
#hiding my private access token
TOKEN = 'xxx'
HEADERS = {'Authorization': f'token {TOKEN}'}

def clean_company_name(company):
    """Clean up company names."""
    if company:
        return company.strip().lstrip('@').upper()
    return None

def get_users_in_zurich():
    url = 'https://api.github.com/search/users'
    all_users = []
    page = 1
    per_page = 100  # Max number of results per page

    while True:
        params = {'q': 'location:Zurich followers:>50', 'page': page, 'per_page': per_page}
        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error fetching users: {response.status_code}")
            break

        users = response.json().get('items', [])
        total_count = response.json().get('total_count', 0)

        if not users:
            print("No more users found.")
            break  # Exit if no more users are found

        all_users.extend(users)
        print(f"Fetched page {page}: {len(users)} users, total fetched: {len(all_users)}")

        # Check if we've fetched all users
        if len(all_users) >= total_count:
            break

        page += 1
        time.sleep(4)  # Throttle requests to avoid rate limiting

    return all_users

def get_user_details(username):
    url = f'https://api.github.com/users/{username}'
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        print(f"Error fetching details for {username}: {response.status_code}")
        return {}

    return response.json()

def main():
    users = get_users_in_zurich()

    # Create a list to store user data
    user_data = []

    for user in users:
        username = user['login']
        print(f'Fetching details for: {username}')

        user_details = get_user_details(username)

        # Extract relevant details
        user_info = {
            'login': user_details.get('login'),
            'name': user_details.get('name'),
            'company': clean_company_name(user_details.get('company')),
            'location': user_details.get('location'),
            'email': user_details.get('email'),
            'hireable': user_details.get('hireable'),
            'bio': user_details.get('bio'),
            'public_repos': user_details.get('public_repos'),
            'followers': user_details.get('followers'),
            'following': user_details.get('following'),
            'created_at': user_details.get('created_at'),
        }

        user_data.append(user_info)

        # Wait for 4 seconds before the next request
        time.sleep(4)

    # Convert the list of user data to a DataFrame
    df = pd.DataFrame(user_data)
    print(len(df))
    # Save the DataFrame to a CSV file
    df.to_csv('users.csv', index=False)
    print("Data saved to users.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetched page 1: 100 users, total fetched: 100
# Fetched page 2: 100 users, total fetched: 200
# Fetched page 3: 100 users, total fetched: 300
# Fetched page 4: 100 users, total fetched: 400
# Fetched page 5: 74 users, total fetched: 474
# Fetching details for: IDouble
# Fetching details for: TheOfficialFloW
# Fetching details for: Seldaek
# Fetching details for: riscv
# Fetching details for: JonnyBurger
# Fetching details for: bpasero
# Fetching details for: egamma
# Fetching details for: ethz-asl
# Fetching details for: sahildua2305
# Fetching details for: joaomoreno
# Fetching details for: klaudiosinani
# Fetching details for: sbrannen
# Fetching details for: Juriy
# Fetching details for: sarlinpe
# Fetching details for: sustrik
# Fetching details for: LorenzMeier
# Fetching details for: jwagner
# Fetching details for: jaspervdj
# Fetching details for: lsmith77
# Fetching details for: videlalvaro
# Fetching details for: cvg
# Fetching details for: filipw
# Fetching details for: SimonHoiberg
# Fetching details for: daviddao
# Fetching details for: FujiwaraChoki
# Fetching details for: sandy081
# Fetching details for: mhils
# Fetching details for: decanus
# Fetching details for: simonaco
# Fetching details for: vegasbrianc
# Fetching details for: betatim
# Fetching details for: Jaeyoung-Lim
# Fetching details for: michaelstaib
# Fetching details for: izuzak
# Fetching details for: cdecker
# Fetching details for: akosma
# Fetching details for: CMU-SAFARI
# Fetching details for: niosus
# Fetching details for: swissspidy
# Fetching details for: tgraf
# Fetching details for: squix78
# Fetching details for: ANYbotics
# Fetching details for: jantimon
# Fetching details for: lucas-clemente
# Fetching details for: mpvl
# Fetching details for: tibbe
# Fetching details for: stefanzweifel
# Fetching details for: gionkunz
# Fetching details for: junpenglao
# Fetching details for: anishLearnsToCode
# Fetching details for: eregon
# Fetching details for: ddvk
# Fetching details for: AVGP
# Fetching details for: kasuken
# Fetching details for: nashory
# Fetching details for: whummer
# Fetching details for: RalucaNicola
# Fetching details for: viatsko
# Fetching details for: klugjo
# Fetching details for: reyk
# Fetching details for: CalciferZh
# Fetching details for: cansik
# Fetching details for: oneThousand1000
# Fetching details for: mihaidusmanu
# Fetching details for: vterron
# Fetching details for: grssnbchr
# Fetching details for: stoeffel
# Fetching details for: jfree
# Fetching details for: 0xB10C
# Fetching details for: isidorn
# Fetching details for: Ha0Tang
# Fetching details for: densh
# Fetching details for: matteocourthoud
# Fetching details for: cfo
# Fetching details for: matthiask
# Fetching details for: kmader
# Fetching details for: jianchao-li
# Fetching details for: Tarrasch
# Fetching details for: deutranium
# Fetching details for: pfankhauser
# Fetching details for: albertpumarola
# Fetching details for: maxim5
# Fetching details for: MichaelFYang
# Fetching details for: pixhawk
# Fetching details for: oscardelben
# Fetching details for: burdges
# Fetching details for: dobin
# Fetching details for: reyammer
# Fetching details for: dlemmermann
# Fetching details for: alexliniger
# Fetching details for: ShengyuH
# Fetching details for: PruneTruong
# Fetching details for: marcbachmann
# Fetching details for: Mayankm96
# Fetching details for: mmaechler
# Fetching details for: cblichmann
# Fetching details for: thomaswue
# Fetching details for: ruflin
# Fetching details for: bndr
# Fetching details for: ChilliCream
# Fetching details for: xldenis
# Fetching details for: B1ueber2y
# Fetching details for: Zhaozixiang1228
# Fetching details for: Separius
# Fetching details for: prs-eth
# Fetching details for: ethz-adrl
# Fetching details for: maria
# Fetching details for: fpgasystems
# Fetching details for: elliottash
# Fetching details for: nmattia
# Fetching details for: abewley
# Fetching details for: ClashLuke
# Fetching details for: mweibel
# Fetching details for: ywcmaike
# Fetching details for: spadgos
# Fetching details for: filiphr
# Fetching details for: alina-yur
# Fetching details for: kaidul
# Fetching details for: fab-jul
# Fetching details for: simonlynen
# Fetching details for: weinand
# Fetching details for: AIWintermuteAI
# Fetching details for: pimvanpelt
# Fetching details for: lvandeve
# Fetching details for: ilyabo
# Fetching details for: sinaahmadi
# Fetching details for: gyglim
# Fetching details for: eastskykang
# Fetching details for: openwms
# Fetching details for: abertschi
# Fetching details for: ChrisJohnRiley
# Fetching details for: ytakzk
# Fetching details for: SafeExamBrowser
# Fetching details for: mrcjkb
# Fetching details for: BILLXZY1215
# Fetching details for: jankais3r
# Fetching details for: gonzalocasas
# Fetching details for: antonilo
# Fetching details for: RMeli
# Fetching details for: ovysotska
# Fetching details for: ContainerSolutions
# Fetching details for: Mauin
# Fetching details for: matteodem
# Fetching details for: xzyaoi
# Fetching details for: biboudis
# Fetching details for: pflammertsma
# Fetching details for: marcoancona
# Fetching details for: rstaib
# Fetching details for: SELISEdigitalplatforms
# Fetching details for: Sadullah-TANRIKULU
# Fetching details for: zhengyuf
# Fetching details for: scipag
# Fetching details for: iuliagroza
# Fetching details for: meetvora
# Fetching details for: karlkurzer
# Fetching details for: maria-korosteleva
# Fetching details for: akolesnikoff
# Fetching details for: dhil
# Fetching details for: Semaserg
# Fetching details for: noeltock
# Fetching details for: aiday-mar
# Fetching details for: syzer
# Fetching details for: domwoe
# Fetching details for: nicnocquee
# Fetching details for: ludoro
# Fetching details for: cyrilwanner
# Fetching details for: HanqingWangAI
# Fetching details for: joaofaro
# Fetching details for: lupas
# Fetching details for: riscv-admin
# Fetching details for: LaurentNevou
# Fetching details for: meiersi
# Fetching details for: fphilipe
# Fetching details for: jannisborn
# Fetching details for: lorenzwalthert
# Fetching details for: zgojcic
# Fetching details for: ShuhangGu
# Fetching details for: bernardopires
# Fetching details for: RinteRface
# Fetching details for: yangycpku
# Fetching details for: ColinFinck
# Fetching details for: mauro3
# Fetching details for: christophsax
# Fetching details for: MoyGcc
# Fetching details for: RagnarGrootKoerkamp
# Fetching details for: FangjinhuaWang
# Fetching details for: dirmeier
# Fetching details for: zarubaf
# Fetching details for: hfp
# Fetching details for: RomanBapst
# Fetching details for: jonasrothfuss
# Fetching details for: gilvegliach
# Fetching details for: renggli
# Fetching details for: kynan
# Fetching details for: IgorSusmelj
# Fetching details for: VladUreche
# Fetching details for: ofsoundof
# Fetching details for: njavet
# Fetching details for: greschd
# Fetching details for: pcko1
# Fetching details for: matthias-springer
# Fetching details for: maxkueng
# Fetching details for: openscript
# Fetching details for: janhohenheim
# Fetching details for: michellesanver
# Fetching details for: schweikert
# Fetching details for: weblucas
# Fetching details for: nilq
# Fetching details for: duguyue100
# Fetching details for: beniwohli
# Fetching details for: bhbr
# Fetching details for: splendido
# Fetching details for: gurkirt
# Fetching details for: dougxc
# Fetching details for: 19reborn
# Fetching details for: victorreijgwart
# Fetching details for: metaodi
# Fetching details for: zc-alexfan
# Fetching details for: gmile
# Fetching details for: markkua
# Fetching details for: joelbarmettlerUZH
# Fetching details for: edinsoncs
# Fetching details for: bermanmaxim
# Fetching details for: bartoszmajsak
# Fetching details for: Zzh2000
# Fetching details for: MeteoSwiss
# Fetching details for: nanoant
# Fetching details for: ffurrer
# Fetching details for: jaimefrio
# Fetching details for: sspreitzer
# Fetching details for: carstein
# Fetching details for: qinenergy
# Fetching details for: maxvfischer
# Fetching details for: lorenwel
# Fetching details for: nikitardn
# Fetching details for: tobiasfshr
# Fetching details for: FinalAngel
# Fetching details for: junwoo091400
# Fetching details for: alexef
# Fetching details for: eth-ait
# Fetching details for: jpuigcerver
# Fetching details for: engelju
# Fetching details for: lukaselmer
# Fetching details for: d909b
# Fetching details for: DonkeyShot21
# Fetching details for: paytonrules
# Fetching details for: WGierke
# Fetching details for: jsnell
# Fetching details for: markomih
# Fetching details for: davidbauer
# Fetching details for: simonschiller
# Fetching details for: adridadou
# Fetching details for: enricobacis
# Fetching details for: pboos
# Fetching details for: zero9178
# Fetching details for: zhendongsu
# Fetching details for: visini
# Fetching details for: mms-gianni
# Fetching details for: markrobinsonuzh
# Fetching details for: ulugbekna
# Fetching details for: lbolla
# Fetching details for: davidknezic
# Fetching details for: etrulls
# Fetching details for: mfehr
# Fetching details for: pavelzw
# Fetching details for: gocarlos
# Fetching details for: paulstarke
# Fetching details for: AnotherKamila
# Fetching details for: adamant-pwn
# Fetching details for: DeAngelisA
# Fetching details for: N2D4
# Fetching details for: tobru
# Fetching details for: mbannert
# Fetching details for: enisimsar
# Fetching details for: weders
# Fetching details for: kysucix
# Fetching details for: patricksnape
# Fetching details for: marionschleifer
# Fetching details for: definelicht
# Fetching details for: glynos
# Fetching details for: monfera
# Fetching details for: Civil
# Fetching details for: palladius
# Fetching details for: mrossinek
# Fetching details for: jiaxi-jiang
# Fetching details for: dlsc-software-consulting-gmbh
# Fetching details for: tbocek
# Fetching details for: juliand665
# Fetching details for: sdierauf
# Fetching details for: DaryaZareM
# Fetching details for: mpascariu
# Fetching details for: rohit01
# Fetching details for: delay
# Fetching details for: kimpers
# Fetching details for: animeshtrivedi
# Fetching details for: AlessioTonioni
# Fetching details for: Nikasa1889
# Fetching details for: ZurichNLP
# Fetching details for: cynkra
# Fetching details for: gokul-uf
# Fetching details for: objecthub
# Fetching details for: rberenguel
# Fetching details for: dan2k3k4
# Fetching details for: aymenfurter
# Fetching details for: magehrig
# Fetching details for: zita-ch
# Fetching details for: CLIMADA-project
# Fetching details for: marco-fp
# Fetching details for: vcaen
# Fetching details for: mandulaj
# Fetching details for: rangsimanketkaew
# Fetching details for: EPMatt
# Fetching details for: shao-hua-li
# Fetching details for: lamyiowce
# Fetching details for: Cryoris
# Fetching details for: yccgabby
# Fetching details for: Abhiroop
# Fetching details for: Amsterdam-gov
# Fetching details for: jasha64
# Fetching details for: antoinealb
# Fetching details for: max-vogler
# Fetching details for: SunHao-0
# Fetching details for: uwolfer
# Fetching details for: fauconnier
# Fetching details for: gildor478
# Fetching details for: behrooz-tahanzadeh
# Fetching details for: dulucas
# Fetching details for: mathause
# Fetching details for: donghao51
# Fetching details for: ThingPulse
# Fetching details for: agostbiro
# Fetching details for: lukebuehler
# Fetching details for: vastsoun
# Fetching details for: gseitz
# Fetching details for: dw5
# Fetching details for: sergiotocalini
# Fetching details for: MartinHahner
# Fetching details for: iwangu
# Fetching details for: dcordero
# Fetching details for: nopper
# Fetching details for: stackoverflow
# Fetching details for: munterfi
# Fetching details for: lejoe
# Fetching details for: birchera
# Fetching details for: kelia
# Fetching details for: mzdr
# Fetching details for: luca-moser
# Fetching details for: rschlaefli
# Fetching details for: lris
# Fetching details for: danacr
# Fetching details for: massich
# Fetching details for: nicomazz
# Fetching details for: ThreeFx
# Fetching details for: nmarincic
# Fetching details for: carlfriess
# Fetching details for: cmaraziaris
# Fetching details for: gsmachado
# Fetching details for: davidoort
# Fetching details for: EliiseS
# Fetching details for: ezzarghili
# Fetching details for: ymattw
# Fetching details for: KasparEtter
# Fetching details for: tomvanmele
# Fetching details for: jeremystucki
# Fetching details for: AWehenkel
# Fetching details for: rinikerlab
# Fetching details for: jingchengchen-com
# Fetching details for: foehnx
# Fetching details for: lizuoyue
# Fetching details for: unidesigner
# Fetching details for: J22Melody
# Fetching details for: BlockResearchGroup
# Fetching details for: zimrick
# Fetching details for: cjeker
# Fetching details for: computational-psychiatry-course
# Fetching details for: sanweiliti
# Fetching details for: yati-sagade
# Fetching details for: alexvicegrab
# Fetching details for: christiandelbianco
# Fetching details for: viperproject
# Fetching details for: rafaelkallis
# Fetching details for: suryanshkumar
# Fetching details for: pmagaz
# Fetching details for: tutunarsl
# Fetching details for: eth-easl
# Fetching details for: ratschlab
# Fetching details for: davidnbresch
# Fetching details for: gskbyte
# Fetching details for: kekeblom
# Fetching details for: fbornhofen
# Fetching details for: stefanhaustein
# Fetching details for: stefanobaghino
# Fetching details for: tobidelbruck
# Fetching details for: alxschwrz
# Fetching details for: cfernandezlab
# Fetching details for: aleximmer
# Fetching details for: alshabib
# Fetching details for: bonevbs
# Fetching details for: onrunning
# Fetching details for: WenqiJiang
# Fetching details for: m2kulkarni
# Fetching details for: 0xabu
# Fetching details for: interrogator
# Fetching details for: dcetin
# Fetching details for: tobiasvonarx
# Fetching details for: lucat1
# Fetching details for: qcscine
# Fetching details for: benschlueter
# Fetching details for: pacoita
# Fetching details for: rozumden
# Fetching details for: signalwerk
# Fetching details for: eile
# Fetching details for: christianbuck
# Fetching details for: ffelten
# Fetching details for: StrawbrryFlurry
# Fetching details for: aycatakmaz
# Fetching details for: maruthven
# Fetching details for: ioanamoraru14
# Fetching details for: jkflying
# Fetching details for: armsp
# Fetching details for: srfdata
# Fetching details for: vorushin
# Fetching details for: mjlm
# Fetching details for: markiv
# Fetching details for: koffeinfrei
# Fetching details for: jscriptcoder
# Fetching details for: zj-dong
# Fetching details for: saveriob
# Fetching details for: clisztian
# Fetching details for: balgan
# Fetching details for: Chive
# Fetching details for: zhejz
# Fetching details for: rgoldade
# Fetching details for: IngmarStein
# Fetching details for: brade31919
# Fetching details for: cimeister
# Fetching details for: codebuff
# Fetching details for: dhananjaysathe
# Fetching details for: jvgomez
# Fetching details for: tobias-tengler
# Fetching details for: dlaptev
# Fetching details for: abossard
# Fetching details for: paddyzab
# Fetching details for: maveonair
# Fetching details for: younies
# Fetching details for: xing89qs
# Fetching details for: scannells
# Fetching details for: manuelstofer
# Fetching details for: guglielmocamporese
# Fetching details for: cstancu
# Fetching details for: FrancoFernando
# Fetching details for: sashashakun
# Fetching details for: pstutz
# Fetching details for: sbliven
# Fetching details for: Javier-varez
# Fetching details for: joslat
# Fetching details for: yenicelik
# Fetching details for: stefan-woerner
# Fetching details for: tatp22
# Fetching details for: LVala
# Fetching details for: WhiteFireFox
# Fetching details for: kolloch
# Fetching details for: NDresevic
# Fetching details for: mmathys
# Fetching details for: gavincangan
# Fetching details for: arnofiva
# Fetching details for: SDAChess
# Fetching details for: algattik
# Fetching details for: lukstafi
# Fetching details for: vxsx
# Fetching details for: bianan
# Fetching details for: dmengelt
# Fetching details for: xarthurx
# Fetching details for: panterch
# 474
# Data saved to users.csv

# %%
import requests
import pandas as pd
import time

# Replace with your GitHub token
#hiding my private access token
TOKEN = 'xxx'
HEADERS = {'Authorization': f'token {TOKEN}'}

def check_rate_limit():
    """Check the current rate limit and wait if necessary."""
    url = 'https://api.github.com/rate_limit'
    response = requests.get(url, headers=HEADERS)

    if response.status_code != 200:
        print(f"Error checking rate limit: {response.status_code}")
        return True  # Treat as if we are over the limit to avoid further requests

    rate_limits = response.json()
    remaining = rate_limits['rate']['remaining']
    reset_time = rate_limits['rate']['reset']

    if remaining == 0:
        wait_time = reset_time - int(time.time())
        print(f"Rate limit exceeded. Waiting for {wait_time} seconds.")
        time.sleep(wait_time + 10)  # Wait until reset + some buffer time
        return False  # After waiting, we can continue

    return True  # Rate limit is fine

def fetch_repositories(username):
    """Fetch up to 500 most recently pushed repositories for a given user."""
    url = f'https://api.github.com/users/{username}/repos'
    params = {
        'sort': 'pushed',
        'direction': 'desc',
        'per_page': 100,
        'page': 1
    }

    all_repos = []

    while True:
        if not check_rate_limit():
            continue  # Check the rate limit again after waiting

        response = requests.get(url, headers=HEADERS, params=params)
        if response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.status_code}")
            break

        repos = response.json()
        if not repos:
            break

        all_repos.extend(repos)

        # Check if we've fetched 500 or more
        if len(all_repos) >= 500:
            break

        params['page'] += 1
        time.sleep(1)  # Throttle requests to avoid hitting rate limits

    # Return the first 500 repositories
    return all_repos[:500]

def main():
    # Read users from users.csv
    users_df = pd.read_csv('users.csv')

    repository_data = []

    for index, row in users_df.iterrows():
        username = row['login']  # Assuming the column is named 'login'
        print(f'Fetching repositories for: {username}')

        repos = fetch_repositories(username)

        for repo in repos:
            repository_info = {
                'login': username,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo.get('has_projects', False),
                'has_wiki': repo.get('has_wiki', False),
                'license_name': repo['license']['name'] if repo.get('license') else None,
            }
            repository_data.append(repository_info)

        time.sleep(4)  # Throttle requests between different users

    # Create a DataFrame and save to CSV
    repositories_df = pd.DataFrame(repository_data)
    repositories_df.to_csv('repositories.csv', index=False)
    print("Data saved to repositories.csv")
    print(len(repositories_df))

if __name__ == "__main__":
    main()
# Out:
# Fetching repositories for: IDouble
# Fetching repositories for: TheOfficialFloW
# Fetching repositories for: Seldaek
# Fetching repositories for: riscv
# Fetching repositories for: JonnyBurger
# Fetching repositories for: bpasero
# Fetching repositories for: egamma
# Fetching repositories for: ethz-asl
# Fetching repositories for: sahildua2305
# Fetching repositories for: joaomoreno
# Fetching repositories for: klaudiosinani
# Fetching repositories for: sbrannen
# Fetching repositories for: Juriy
# Fetching repositories for: sarlinpe
# Fetching repositories for: sustrik
# Fetching repositories for: LorenzMeier
# Fetching repositories for: jwagner
# Fetching repositories for: jaspervdj
# Fetching repositories for: lsmith77
# Fetching repositories for: videlalvaro
# Fetching repositories for: cvg
# Fetching repositories for: filipw
# Fetching repositories for: SimonHoiberg
# Fetching repositories for: daviddao
# Fetching repositories for: FujiwaraChoki
# Fetching repositories for: sandy081
# Fetching repositories for: mhils
# Fetching repositories for: decanus
# Fetching repositories for: simonaco
# Fetching repositories for: vegasbrianc
# Fetching repositories for: betatim
# Fetching repositories for: Jaeyoung-Lim
# Fetching repositories for: michaelstaib
# Fetching repositories for: izuzak
# Fetching repositories for: cdecker
# Fetching repositories for: akosma
# Fetching repositories for: CMU-SAFARI
# Fetching repositories for: niosus
# Fetching repositories for: swissspidy
# Fetching repositories for: tgraf
# Fetching repositories for: squix78
# Fetching repositories for: ANYbotics
# Fetching repositories for: jantimon
# Fetching repositories for: lucas-clemente
# Fetching repositories for: mpvl
# Fetching repositories for: tibbe
# Fetching repositories for: stefanzweifel
# Fetching repositories for: gionkunz
# Fetching repositories for: junpenglao
# Fetching repositories for: anishLearnsToCode
# Fetching repositories for: eregon
# Fetching repositories for: ddvk
# Fetching repositories for: AVGP
# Fetching repositories for: kasuken
# Fetching repositories for: nashory
# Fetching repositories for: whummer
# Fetching repositories for: RalucaNicola
# Fetching repositories for: viatsko
# Fetching repositories for: klugjo
# Fetching repositories for: reyk
# Fetching repositories for: CalciferZh
# Fetching repositories for: cansik
# Fetching repositories for: oneThousand1000
# Fetching repositories for: mihaidusmanu
# Fetching repositories for: vterron
# Fetching repositories for: grssnbchr
# Fetching repositories for: stoeffel
# Fetching repositories for: jfree
# Fetching repositories for: 0xB10C
# Fetching repositories for: isidorn
# Fetching repositories for: Ha0Tang
# Fetching repositories for: densh
# Fetching repositories for: matteocourthoud
# Fetching repositories for: cfo
# Fetching repositories for: matthiask
# Fetching repositories for: kmader
# Fetching repositories for: jianchao-li
# Fetching repositories for: Tarrasch
# Fetching repositories for: deutranium
# Fetching repositories for: pfankhauser
# Fetching repositories for: albertpumarola
# Fetching repositories for: maxim5
# Fetching repositories for: MichaelFYang
# Fetching repositories for: pixhawk
# Fetching repositories for: oscardelben
# Fetching repositories for: burdges
# Fetching repositories for: dobin
# Fetching repositories for: reyammer
# Fetching repositories for: dlemmermann
# Fetching repositories for: alexliniger
# Fetching repositories for: ShengyuH
# Fetching repositories for: PruneTruong
# Fetching repositories for: marcbachmann
# Fetching repositories for: Mayankm96
# Fetching repositories for: mmaechler
# Fetching repositories for: cblichmann
# Fetching repositories for: thomaswue
# Fetching repositories for: ruflin
# Fetching repositories for: bndr
# Fetching repositories for: ChilliCream
# Fetching repositories for: xldenis
# Fetching repositories for: B1ueber2y
# Fetching repositories for: Zhaozixiang1228
# Fetching repositories for: Separius
# Fetching repositories for: prs-eth
# Fetching repositories for: ethz-adrl
# Fetching repositories for: maria
# Fetching repositories for: fpgasystems
# Fetching repositories for: elliottash
# Fetching repositories for: nmattia
# Fetching repositories for: abewley
# Fetching repositories for: ClashLuke
# Fetching repositories for: mweibel
# Fetching repositories for: ywcmaike
# Fetching repositories for: spadgos
# Fetching repositories for: filiphr
# Fetching repositories for: alina-yur
# Fetching repositories for: kaidul
# Fetching repositories for: fab-jul
# Fetching repositories for: simonlynen
# Fetching repositories for: weinand
# Fetching repositories for: AIWintermuteAI
# Fetching repositories for: pimvanpelt
# Fetching repositories for: lvandeve
# Fetching repositories for: ilyabo
# Fetching repositories for: sinaahmadi
# Fetching repositories for: gyglim
# Fetching repositories for: eastskykang
# Fetching repositories for: openwms
# Fetching repositories for: abertschi
# Fetching repositories for: ChrisJohnRiley
# Fetching repositories for: ytakzk
# Fetching repositories for: SafeExamBrowser
# Fetching repositories for: mrcjkb
# Fetching repositories for: BILLXZY1215
# Fetching repositories for: jankais3r
# Fetching repositories for: gonzalocasas
# Fetching repositories for: antonilo
# Fetching repositories for: RMeli
# Fetching repositories for: ovysotska
# Fetching repositories for: ContainerSolutions
# Fetching repositories for: Mauin
# Fetching repositories for: matteodem
# Fetching repositories for: xzyaoi
# Fetching repositories for: biboudis
# Fetching repositories for: pflammertsma
# Fetching repositories for: marcoancona
# Fetching repositories for: rstaib
# Fetching repositories for: SELISEdigitalplatforms
# Fetching repositories for: Sadullah-TANRIKULU
# Fetching repositories for: zhengyuf
# Fetching repositories for: scipag
# Fetching repositories for: iuliagroza
# Fetching repositories for: meetvora
# Fetching repositories for: karlkurzer
# Fetching repositories for: maria-korosteleva
# Fetching repositories for: akolesnikoff
# Fetching repositories for: dhil
# Fetching repositories for: Semaserg
# Fetching repositories for: noeltock
# Fetching repositories for: aiday-mar
# Fetching repositories for: syzer
# Fetching repositories for: domwoe
# Fetching repositories for: nicnocquee
# Fetching repositories for: ludoro
# Fetching repositories for: cyrilwanner
# Fetching repositories for: HanqingWangAI
# Fetching repositories for: joaofaro
# Fetching repositories for: lupas
# Fetching repositories for: riscv-admin
# Fetching repositories for: LaurentNevou
# Fetching repositories for: meiersi
# Fetching repositories for: fphilipe
# Fetching repositories for: jannisborn
# Fetching repositories for: lorenzwalthert
# Fetching repositories for: zgojcic
# Fetching repositories for: ShuhangGu
# Fetching repositories for: bernardopires
# Fetching repositories for: RinteRface
# Fetching repositories for: yangycpku
# Fetching repositories for: ColinFinck
# Fetching repositories for: mauro3
# Fetching repositories for: christophsax
# Fetching repositories for: MoyGcc
# Fetching repositories for: RagnarGrootKoerkamp
# Fetching repositories for: FangjinhuaWang
# Fetching repositories for: dirmeier
# Fetching repositories for: zarubaf
# Fetching repositories for: hfp
# Fetching repositories for: RomanBapst
# Fetching repositories for: jonasrothfuss
# Fetching repositories for: gilvegliach
# Fetching repositories for: renggli
# Fetching repositories for: kynan
# Fetching repositories for: IgorSusmelj
# Fetching repositories for: VladUreche
# Fetching repositories for: ofsoundof
# Fetching repositories for: njavet
# Fetching repositories for: greschd
# Fetching repositories for: pcko1
# Fetching repositories for: matthias-springer
# Fetching repositories for: maxkueng
# Fetching repositories for: openscript
# Fetching repositories for: janhohenheim
# Fetching repositories for: michellesanver
# Fetching repositories for: schweikert
# Fetching repositories for: weblucas
# Fetching repositories for: nilq
# Fetching repositories for: duguyue100
# Fetching repositories for: beniwohli
# Fetching repositories for: bhbr
# Fetching repositories for: splendido
# Fetching repositories for: gurkirt
# Fetching repositories for: dougxc
# Fetching repositories for: 19reborn
# Fetching repositories for: victorreijgwart
# Fetching repositories for: metaodi
# Fetching repositories for: zc-alexfan
# Fetching repositories for: gmile
# Fetching repositories for: markkua
# Fetching repositories for: joelbarmettlerUZH
# Fetching repositories for: edinsoncs
# Fetching repositories for: bermanmaxim
# Fetching repositories for: bartoszmajsak
# Fetching repositories for: Zzh2000
# Fetching repositories for: MeteoSwiss
# Fetching repositories for: nanoant
# Fetching repositories for: ffurrer
# Fetching repositories for: jaimefrio
# Fetching repositories for: sspreitzer
# Fetching repositories for: carstein
# Fetching repositories for: qinenergy
# Fetching repositories for: maxvfischer
# Fetching repositories for: lorenwel
# Fetching repositories for: nikitardn
# Fetching repositories for: tobiasfshr
# Fetching repositories for: FinalAngel
# Fetching repositories for: junwoo091400
# Fetching repositories for: alexef
# Fetching repositories for: eth-ait
# Fetching repositories for: jpuigcerver
# Fetching repositories for: engelju
# Fetching repositories for: lukaselmer
# Fetching repositories for: d909b
# Fetching repositories for: DonkeyShot21
# Fetching repositories for: paytonrules
# Fetching repositories for: WGierke
# Fetching repositories for: jsnell
# Fetching repositories for: markomih
# Fetching repositories for: davidbauer
# Fetching repositories for: simonschiller
# Fetching repositories for: adridadou
# Fetching repositories for: enricobacis
# Fetching repositories for: pboos
# Fetching repositories for: zero9178
# Fetching repositories for: zhendongsu
# Fetching repositories for: visini
# Fetching repositories for: mms-gianni
# Fetching repositories for: markrobinsonuzh
# Fetching repositories for: ulugbekna
# Fetching repositories for: lbolla
# Fetching repositories for: davidknezic
# Fetching repositories for: etrulls
# Fetching repositories for: mfehr
# Fetching repositories for: pavelzw
# Fetching repositories for: gocarlos
# Fetching repositories for: paulstarke
# Fetching repositories for: AnotherKamila
# Fetching repositories for: adamant-pwn
# Fetching repositories for: DeAngelisA
# Fetching repositories for: N2D4
# Fetching repositories for: tobru
# Fetching repositories for: mbannert
# Fetching repositories for: enisimsar
# Fetching repositories for: weders
# Fetching repositories for: kysucix
# Fetching repositories for: patricksnape
# Fetching repositories for: marionschleifer
# Fetching repositories for: definelicht
# Fetching repositories for: glynos
# Fetching repositories for: monfera
# Fetching repositories for: Civil
# Fetching repositories for: palladius
# Fetching repositories for: mrossinek
# Fetching repositories for: jiaxi-jiang
# Fetching repositories for: dlsc-software-consulting-gmbh
# Fetching repositories for: tbocek
# Fetching repositories for: juliand665
# Fetching repositories for: sdierauf
# Fetching repositories for: DaryaZareM
# Fetching repositories for: mpascariu
# Fetching repositories for: rohit01
# Fetching repositories for: delay
# Fetching repositories for: kimpers
# Fetching repositories for: animeshtrivedi
# Fetching repositories for: AlessioTonioni
# Fetching repositories for: Nikasa1889
# Fetching repositories for: ZurichNLP
# Fetching repositories for: cynkra
# Fetching repositories for: gokul-uf
# Fetching repositories for: objecthub
# Fetching repositories for: rberenguel
# Fetching repositories for: dan2k3k4
# Fetching repositories for: aymenfurter
# Fetching repositories for: magehrig
# Fetching repositories for: zita-ch
# Fetching repositories for: CLIMADA-project
# Fetching repositories for: marco-fp
# Fetching repositories for: vcaen
# Fetching repositories for: mandulaj
# Fetching repositories for: rangsimanketkaew
# Fetching repositories for: EPMatt
# Fetching repositories for: shao-hua-li
# Fetching repositories for: lamyiowce
# Fetching repositories for: Cryoris
# Fetching repositories for: yccgabby
# Fetching repositories for: Abhiroop
# Fetching repositories for: Amsterdam-gov
# Fetching repositories for: jasha64
# Fetching repositories for: antoinealb
# Fetching repositories for: max-vogler
# Fetching repositories for: SunHao-0
# Fetching repositories for: uwolfer
# Fetching repositories for: fauconnier
# Fetching repositories for: gildor478
# Fetching repositories for: behrooz-tahanzadeh
# Fetching repositories for: dulucas
# Fetching repositories for: mathause
# Fetching repositories for: donghao51
# Fetching repositories for: ThingPulse
# Fetching repositories for: agostbiro
# Fetching repositories for: lukebuehler
# Fetching repositories for: vastsoun
# Fetching repositories for: gseitz
# Fetching repositories for: dw5
# Fetching repositories for: sergiotocalini
# Fetching repositories for: MartinHahner
# Fetching repositories for: iwangu
# Fetching repositories for: dcordero
# Fetching repositories for: nopper
# Fetching repositories for: stackoverflow
# Fetching repositories for: munterfi
# Fetching repositories for: lejoe
# Fetching repositories for: birchera
# Fetching repositories for: kelia
# Fetching repositories for: mzdr
# Fetching repositories for: luca-moser
# Fetching repositories for: rschlaefli
# Fetching repositories for: lris
# Fetching repositories for: danacr
# Fetching repositories for: massich
# Fetching repositories for: nicomazz
# Fetching repositories for: ThreeFx
# Fetching repositories for: nmarincic
# Fetching repositories for: carlfriess
# Fetching repositories for: cmaraziaris
# Fetching repositories for: gsmachado
# Fetching repositories for: davidoort
# Fetching repositories for: EliiseS
# Fetching repositories for: ezzarghili
# Fetching repositories for: ymattw
# Fetching repositories for: KasparEtter
# Fetching repositories for: tomvanmele
# Fetching repositories for: jeremystucki
# Fetching repositories for: AWehenkel
# Fetching repositories for: rinikerlab
# Fetching repositories for: jingchengchen-com
# Fetching repositories for: foehnx
# Fetching repositories for: lizuoyue
# Fetching repositories for: unidesigner
# Fetching repositories for: J22Melody
# Fetching repositories for: BlockResearchGroup
# Fetching repositories for: zimrick
# Fetching repositories for: cjeker
# Fetching repositories for: computational-psychiatry-course
# Fetching repositories for: sanweiliti
# Fetching repositories for: yati-sagade
# Fetching repositories for: alexvicegrab
# Fetching repositories for: christiandelbianco
# Fetching repositories for: viperproject
# Fetching repositories for: rafaelkallis
# Fetching repositories for: suryanshkumar
# Fetching repositories for: pmagaz
# Fetching repositories for: tutunarsl
# Fetching repositories for: eth-easl
# Fetching repositories for: ratschlab
# Fetching repositories for: davidnbresch
# Fetching repositories for: gskbyte
# Fetching repositories for: kekeblom
# Fetching repositories for: fbornhofen
# Fetching repositories for: stefanhaustein
# Fetching repositories for: stefanobaghino
# Fetching repositories for: tobidelbruck
# Fetching repositories for: alxschwrz
# Fetching repositories for: cfernandezlab
# Fetching repositories for: aleximmer
# Fetching repositories for: alshabib
# Fetching repositories for: bonevbs
# Fetching repositories for: onrunning
# Fetching repositories for: WenqiJiang
# Fetching repositories for: m2kulkarni
# Fetching repositories for: 0xabu
# Fetching repositories for: interrogator
# Fetching repositories for: dcetin
# Fetching repositories for: tobiasvonarx
# Fetching repositories for: lucat1
# Fetching repositories for: qcscine
# Fetching repositories for: benschlueter
# Fetching repositories for: pacoita
# Fetching repositories for: rozumden
# Fetching repositories for: signalwerk
# Fetching repositories for: eile
# Fetching repositories for: christianbuck
# Fetching repositories for: ffelten
# Fetching repositories for: StrawbrryFlurry
# Fetching repositories for: aycatakmaz
# Fetching repositories for: maruthven
# Fetching repositories for: ioanamoraru14
# Fetching repositories for: jkflying
# Fetching repositories for: armsp
# Fetching repositories for: srfdata
# Fetching repositories for: vorushin
# Fetching repositories for: mjlm
# Fetching repositories for: markiv
# Fetching repositories for: koffeinfrei
# Fetching repositories for: jscriptcoder
# Fetching repositories for: zj-dong
# Fetching repositories for: saveriob
# Fetching repositories for: clisztian
# Fetching repositories for: balgan
# Fetching repositories for: Chive
# Fetching repositories for: zhejz
# Fetching repositories for: rgoldade
# Fetching repositories for: IngmarStein
# Fetching repositories for: brade31919
# Fetching repositories for: cimeister
# Fetching repositories for: codebuff
# Fetching repositories for: dhananjaysathe
# Fetching repositories for: jvgomez
# Fetching repositories for: tobias-tengler
# Fetching repositories for: dlaptev
# Fetching repositories for: abossard
# Fetching repositories for: paddyzab
# Fetching repositories for: maveonair
# Fetching repositories for: younies
# Fetching repositories for: xing89qs
# Fetching repositories for: scannells
# Fetching repositories for: manuelstofer
# Fetching repositories for: guglielmocamporese
# Fetching repositories for: cstancu
# Fetching repositories for: FrancoFernando
# Fetching repositories for: sashashakun
# Fetching repositories for: pstutz
# Fetching repositories for: sbliven
# Fetching repositories for: Javier-varez
# Fetching repositories for: joslat
# Fetching repositories for: yenicelik
# Fetching repositories for: stefan-woerner
# Fetching repositories for: tatp22
# Fetching repositories for: LVala
# Fetching repositories for: WhiteFireFox
# Fetching repositories for: kolloch
# Fetching repositories for: NDresevic
# Fetching repositories for: mmathys
# Fetching repositories for: gavincangan
# Fetching repositories for: arnofiva
# Fetching repositories for: SDAChess
# Fetching repositories for: algattik
# Fetching repositories for: lukstafi
# Fetching repositories for: vxsx
# Fetching repositories for: bianan
# Fetching repositories for: dmengelt
# Fetching repositories for: xarthurx
# Fetching repositories for: panterch
# Data saved to repositories.csv
# 29036

# %%
import pandas as pd

def main():
    # Read the repositories from repositories.csv
    repos_df = pd.read_csv('repositories.csv')

    # Convert 'created_at' to datetime to filter users who joined after 2020
    repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

    # Filter repositories based on the user's creation date
    # Here we assume that the user joined in the year of repository creation
    # If you have a separate column for user join date, adjust this accordingly
    recent_repos_df = repos_df[repos_df['created_at'] >= '2020-01-01']

    # Count the occurrences of each language
    language_counts = recent_repos_df['language'].value_counts()

    # Check if there are at least 2 different languages
    if len(language_counts) < 2:
        print("Not enough languages found.")
        return

    # Get the second most popular language
    second_most_popular = language_counts.index[1]  # Index 1 gives the second most popular

    print(f"The second most popular programming language among users who joined after 2020 is: {second_most_popular}")

if __name__ == "__main__":
    main()
# Out:
# The second most popular programming language among users who joined after 2020 is: JavaScript

# %%
import pandas as pd

def main():
    # Read the repositories from repositories.csv
    repos_df = pd.read_csv('repositories.csv')

    # Group by language and calculate the average number of stars per repository
    average_stars_per_language = repos_df.groupby('language')['stargazers_count'].mean()

    # Find the language with the highest average number of stars
    highest_avg_stars_language = average_stars_per_language.idxmax()
    highest_avg_stars_value = average_stars_per_language.max()

    print(f"The language with the highest average number of stars per repository is: {highest_avg_stars_language}")
    print(f"Average stars per repository: {highest_avg_stars_value:.2f}")

if __name__ == "__main__":
    main()
# Out:
# The language with the highest average number of stars per repository is: BitBake
# Average stars per repository: 364.00

# %%
import pandas as pd

def main():
    # Read the repositories from repositories.csv
    repos_df = pd.read_csv('repositories.csv')

    # Ensure the 'has_projects' and 'has_wiki' columns are boolean
    repos_df['has_projects'] = repos_df['has_projects'].astype(bool)
    repos_df['has_wiki'] = repos_df['has_wiki'].astype(bool)

    # Calculate the correlation between 'has_projects' and 'has_wiki'
    correlation = repos_df['has_projects'].corr(repos_df['has_wiki'])

    print(f"The correlation between projects and wiki enabled is: {correlation:.3f}")

if __name__ == "__main__":
    main()
# Out:
# The correlation between projects and wiki enabled is: 0.312

# %%
import pandas as pd

def main():
    # Read the repositories from repositories.csv
    repos_df = pd.read_csv('repositories.csv')

    # Ensure the 'has_projects' and 'has_wiki' columns are boolean
    repos_df['has_projects'] = repos_df['has_projects'].astype(bool)
    repos_df['has_wiki'] = repos_df['has_wiki'].astype(bool)

    # Calculate the correlation between 'has_projects' and 'has_wiki'
    correlation = repos_df['has_projects'].astype(int).corr(repos_df['has_wiki'].astype(int))

    print(f"The correlation between projects and wiki enabled is: {correlation:.3f}")

if __name__ == "__main__":
    main()
# Out:
# The correlation between projects and wiki enabled is: 0.312

# %%
import pandas as pd

def main():
    # Read the repositories from repositories.csv
    repos_df = pd.read_csv('repositories.csv')

    # Convert 'created_at' to datetime
    repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

    # Extract the day of the week (0=Monday, 6=Sunday)
    repos_df['day_of_week'] = repos_df['created_at'].dt.dayofweek

    # Filter for weekend days (Saturday=5, Sunday=6)
    weekend_repos_df = repos_df[repos_df['day_of_week'].isin([5, 6])]

    # Count the number of repositories created by each user on weekends
    weekend_counts = weekend_repos_df['login'].value_counts()

    # Get the user who created the most on weekends
    if not weekend_counts.empty:
        top_user = weekend_counts.idxmax()
        top_count = weekend_counts.max()
        print(f"The user who created the most repositories on weekends is: {top_user} with {top_count} repositories.")
    else:
        print("No repositories were created on weekends.")

if __name__ == "__main__":
    main()
# Out:
# The user who created the most repositories on weekends is: JonnyBurger with 82 repositories.
